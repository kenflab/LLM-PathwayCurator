# %%
# repo root
# %cd /work
# Out:
# /work

# %%
# !ls
# Out:
# LICENSE    adapters  examples  paper	       scripts	tests
# README.md  docker    out       pyproject.toml  src

# %%
# Fetch from UCSC Xena
# !python paper/scripts/fig2_fetch_inputs.py
# Out:
# [fetch_inputs] OK
#   /work/paper/source_data/PANCAN_TP53_v1/raw/expression.xena.gz
#   /work/paper/source_data/PANCAN_TP53_v1/raw/mc3.v0.2.8.PUBLIC.xena.gz
#   /work/paper/source_data/PANCAN_TP53_v1/raw/TCGA_phenotype_dense.tsv.gz

# %%
# Extract TP53 mutations (mc3.v0.2.8.PUBLIC.xena.gz)
# Create barcode→cancer from phenotype 
# Output derived/groups/{CANCER}.groups.tsv　for each cancer type

# !python paper/scripts/fig2_make_groups.py
# Out:
# [make_groups] sample_type_id raw unique (head): ['07', '06', '05', '03', '02', '01', '11', '']
# [make_groups] sample_type_id norm counts: {'1': 10593, '11': 1475, '6': 396, '3': 200, '': 72, '2': 56, '5': 11, '7': 1}
# [make_groups] filtered to primary-like sample_type_id in {1,3}: 10793
# [make_groups] phenotype mapped samples: 10793
# [make_groups] cancers: ['ACC', 'BLCA', 'BRCA', 'CESC', 'CHOL', 'COAD', 'DLBC', 'ESCA', 'GBM', 'HNSC', 'KICH', 'KIRC', 'KIRP', 'LAML', 'LGG', 'LIHC', 'LUAD', 'LUSC', 'MESO', 'OV', 'PAAD', 'PCPG', 'PRAD', 'READ', 'SARC', 'SKCM', 'STAD', 'TGCT', 'THCA', 'THYM', 'UCEC', 'UCS', 'UVM']
# [make_groups] MC3 TP53 rows: 3729
# [make_groups] MC3 TP53 protein-altering rows (pre-FILTER): 3620
# [make_groups] FILTER column not found; not applying FILTER
# [make_groups] WARNING: LAML has n_mut=0, n_wt=200
# [make_groups] WARNING: UVM has n_mut=0, n_wt=80
# [make_groups] OK
#   wrote: /work/paper/source_data/PANCAN_TP53_v1/derived/groups/PANCAN.groups.tsv
#   cancers: 33
#   samples (mapped): 10793
#   TP53_mut (mapped): 3208

# %%
# !python paper/scripts/fig2_make_sample_cards.py
# Out:
# [make_sample_cards] OK
#   wrote: /work/paper/source_data/PANCAN_TP53_v1/sample_cards (33 cards)

# %%
for c in ("HNSC", "LUAD", "LUSC", "BRCA", "OV",  "UCEC",  "SKCM"):
  # !Rscript paper/scripts/fig2_deg_rank.R $c
# Out:
# [deg_rank] inputs
#   cancer: HNSC
#   expr: /work/paper/source_data/PANCAN_TP53_v1/raw/expression.xena.gz
#   groups: /work/paper/source_data/PANCAN_TP53_v1/derived/groups/HNSC.groups.tsv
# [deg_rank] matched samples: 520  / expr= 11069  / groups= 528
# [deg_rank] QC: dropping zero-variance genes: 269
# [deg_rank] OK
#   wrote: /work/paper/source_data/PANCAN_TP53_v1/derived/rankings/HNSC.deg_ranking.tsv
#   n_genes: 20262
# [deg_rank] inputs
#   cancer: LUAD
#   expr: /work/paper/source_data/PANCAN_TP53_v1/raw/expression.xena.gz
#   groups: /work/paper/source_data/PANCAN_TP53_v1/derived/groups/LUAD.groups.tsv
# [deg_rank] matched samples: 515  / expr= 11069  / groups= 520
# [deg_rank] QC: dropping zero-variance genes: 338
# [deg_rank] OK
#   wrote: /work/paper/source_data/PANCAN_TP53_v1/derived/rankings/LUAD.deg_ranking.tsv
#   n_genes: 20193
# [deg_rank] inputs
#   cancer: LUSC
#   expr: /work/paper/source_data/PANCAN_TP53_v1/raw/expression.xena.gz
#   groups: /work/paper/source_data/PANCAN_TP53_v1/derived/groups/LUSC.groups.tsv
# [deg_rank] matched samples: 502  / expr= 11069  / groups= 506
# [deg_rank] QC: dropping zero-variance genes: 288
# [deg_rank] OK
#   wrote: /work/paper/source_data/PANCAN_TP53_v1/derived/rankings/LUSC.deg_ranking.tsv
#   n_genes: 20243
# [deg_rank] inputs
#   cancer: BRCA
#   expr: /work/paper/source_data/PANCAN_TP53_v1/raw/expression.xena.gz
#   groups: /work/paper/source_data/PANCAN_TP53_v1/derived/groups/BRCA.groups.tsv
# [deg_rank] matched samples: 1097  / expr= 11069  / groups= 1101
# [deg_rank] QC: dropping zero-variance genes: 282
# [deg_rank] OK
#   wrote: /work/paper/source_data/PANCAN_TP53_v1/derived/rankings/BRCA.deg_ranking.tsv
#   n_genes: 20249
# [deg_rank] inputs
#   cancer: OV
#   expr: /work/paper/source_data/PANCAN_TP53_v1/raw/expression.xena.gz
#   groups: /work/paper/source_data/PANCAN_TP53_v1/derived/groups/OV.groups.tsv
# [deg_rank] matched samples: 303  / expr= 11069  / groups= 592
# [deg_rank] QC: dropping zero-variance genes: 1138
# Warning message:
# Partial NA coefficients for 321 probe(s)
# [deg_rank] OK
#   wrote: /work/paper/source_data/PANCAN_TP53_v1/derived/rankings/OV.deg_ranking.tsv
#   n_genes: 19072
# [deg_rank] inputs
#   cancer: UCEC
#   expr: /work/paper/source_data/PANCAN_TP53_v1/raw/expression.xena.gz
#   groups: /work/paper/source_data/PANCAN_TP53_v1/derived/groups/UCEC.groups.tsv
# [deg_rank] matched samples: 532  / expr= 11069  / groups= 547
# [deg_rank] QC: dropping zero-variance genes: 385
# [deg_rank] OK
#   wrote: /work/paper/source_data/PANCAN_TP53_v1/derived/rankings/UCEC.deg_ranking.tsv
#   n_genes: 20146
# [deg_rank] inputs
#   cancer: SKCM
#   expr: /work/paper/source_data/PANCAN_TP53_v1/raw/expression.xena.gz
#   groups: /work/paper/source_data/PANCAN_TP53_v1/derived/groups/SKCM.groups.tsv
# [deg_rank] matched samples: 103  / expr= 11069  / groups= 104
# [deg_rank] QC: dropping zero-variance genes: 450
# [deg_rank] OK
#   wrote: /work/paper/source_data/PANCAN_TP53_v1/derived/rankings/SKCM.deg_ranking.tsv
#   n_genes: 20081

# %%
# !Rscript paper/scripts/fig2_fgsea_to_evidence_table.R HNSC
# Out:
# [fgsea_to_evidence] inputs
#   cancer: HNSC
#   rank: /work/paper/source_data/PANCAN_TP53_v1/derived/rankings/HNSC.deg_ranking.tsv
#   out : /work/paper/source_data/PANCAN_TP53_v1/evidence_tables/HNSC.evidence_table.tsv
#   msigdbr_version: 25.1.1
#   fgsea_version  : 1.36.2
# [fgsea_to_evidence] stats diagnostics
#   stats_len: 20262
#   stats_type: double
#   stats_na: 0
#   stats_range: -12.6721379948078,10.5253182402821
#   gene_example: 4060,6817,5153,1902,19594,9055,6447,16500,1970,8301
#   gene_id_type: entrez
# [fgsea_to_evidence] msigdbr entrez column: ncbi_gene
# [fgsea_to_evidence] overlap diagnostics
#   overlap_summary: min 24 p25 80 median 141 p75 165 max 193
#   pathways_with_overlap>=15: 50 / 50
# [fgsea_to_evidence] fgsea diagnostics
#   n_pathways: 50
#   res_rows  : 50
# [fgsea_to_evidence] OK
#   wrote: /work/paper/source_data/PANCAN_TP53_v1/evidence_tables/HNSC.evidence_table.tsv
#   n_terms: 50

# %%
# Fig2 run
# !python paper/scripts/run_fig2_pipeline.py \
  --cancers HNSC \
  --variants ours \
  --taus 0.2,0.4,0.6,0.8,0.9
# Out:
# [run_fig2] OK
#   out: /work/paper/source_data/PANCAN_TP53_v1/out

# %%
# !ls /work/paper/source_data/PANCAN_TP53_v1/out/HNSC/ours
# Out:
# audit_log.tsv		    report.jsonl	       tau_0.40
# claims.proposed.tsv	    report.md		       tau_0.60
# distilled.tsv		    risk_coverage.tsv	       tau_0.80
# distilled.with_modules.tsv  run_meta.json	       tau_0.90
# evidence.normalized.tsv     sample_card.resolved.json  term_gene_edges.tsv
# modules.tsv		    tau_0.20		       term_modules.tsv

# %%
# !python paper/scripts/fig2_sanity_check.py /work/paper/source_data/PANCAN_TP53_v1/out/HNSC/ours/tau_0.20
# Out:
# BASE: /work/paper/source_data/PANCAN_TP53_v1/out/HNSC/ours/tau_0.20
# report   True 3334
# audit    True 2799
# modules  True 5506
# edges    True 88967
# terms    True 3288
# distilled True 29940
# risk     True 154
# card     True 404
# meta     True 2495
#
# [run_meta] tool/status/step: llm-pathway-curator ok report_jsonl
#
# [report] shape: (3, 35)
# [report] decisions: {'PASS': 3}
# [report] tau unique: [0.2]
# [report] columns (top 25): ['schema_version', 'created_at', 'run_id', 'method', 'cancer', 'comparison', 'tau', 'claim_id', 'decision', 'survival', 'reason_codes', 'context_keys', 'disease', 'tissue', 'perturbation', 'gene_set_hash', 'benchmark_id', 'evidence_refs.module_ids', 'evidence_refs.term_ids', 'evidence_refs.gene_ids', 'evidence_refs.gene_set_hash', 'claim.entity_type', 'claim.entity_id', 'claim.entity_name', 'claim.direction']
#
# [report] contract view (head):
# schema_version   benchmark_id                run_id method cancer          comparison  tau       claim_id decision  survival claim.entity_type                  claim.entity_id claim.direction claim.context.disease claim.context.tissue claim.context.perturbation evidence_refs.gene_set_hash
#             v1 PANCAN_TP53_v1 1768778065_eb84e7fc3a   ours   HNSC TP53_mut_vs_TP53_wt  0.2 c_741409576f21     PASS       1.0           pathway               HALLMARK_APOPTOSIS              up                  HNSC                tumor                   genotype                1b912bf139ec
#             v1 PANCAN_TP53_v1 1768778065_eb84e7fc3a   ours   HNSC TP53_mut_vs_TP53_wt  0.2 c_66fdbb8a7099     PASS       1.0           pathway HALLMARK_CHOLESTEROL_HOMEOSTASIS              up                  HNSC                tumor                   genotype                01a3aafc0275
#             v1 PANCAN_TP53_v1 1768778065_eb84e7fc3a   ours   HNSC TP53_mut_vs_TP53_wt  0.2 c_3b50c19fc934     PASS       1.0           pathway             HALLMARK_P53_PATHWAY              up                  HNSC                tumor                   genotype                73cbba12ef1c
#
# [audit] shape: (3, 31)
# [audit] columns: ['claim_id', 'entity', 'direction', 'context_keys', 'term_uid', 'source', 'term_name', 'module_id', 'module_reason', 'gene_ids', 'term_ids', 'gene_set_hash', 'context_score', 'eligible', 'term_survival', 'keep_term', 'keep_reason', 'claim_json', 'status', 'link_ok', 'stability_ok', 'contradiction_ok', 'stress_ok', 'abstain_reason', 'fail_reason', 'audit_notes', 'term_survival_agg', 'gene_set_hash_effective', 'term_ids_set_hash', 'evidence_key', 'direction_norm']
# [audit] decision counts: {'PASS': 3}
# [SANITY][WARN] audit has no FAIL/ABSTAIN (bench may be too easy for Fig2)
# [audit] top abstain_reason: {'nan': 3}
# [audit] top fail_reason: {'nan': 3}
# [SANITY][WARN] audit_notes all empty/NA (explanations may be too thin for paper)
#
# [audit] head:
#       claim_id                           entity direction                           context_keys                                               term_uid                source                        term_name       module_id  module_reason                                          gene_ids                                               term_ids gene_set_hash  context_score  eligible  term_survival  keep_term keep_reason                                                                                                                                                                                                                                                                                                                                                                           claim_json status  link_ok  stability_ok  contradiction_ok  stress_ok  abstain_reason  fail_reason  audit_notes  term_survival_agg gene_set_hash_effective term_ids_set_hash evidence_key direction_norm
# c_741409576f21               HALLMARK_APOPTOSIS        up disease,tissue,perturbation,comparison               fgsea_msigdb_H_entrez:HALLMARK_APOPTOSIS fgsea_msigdb_H_entrez               HALLMARK_APOPTOSIS M0001__0df48c1b            NaN  4060,1499,7818,6304,5970,3301,4000,633,2879,3482               fgsea_msigdb_H_entrez:HALLMARK_APOPTOSIS  1b912bf139ec              0      True            1.0       True          ok                             {"claim_id":"c_741409576f21","entity":"HALLMARK_APOPTOSIS","direction":"up","context_keys":["disease","tissue","perturbation","comparison"],"evidence_ref":{"module_id":"M0001__0df48c1b","gene_ids":["4060","1499","7818","6304","5970","3301","4000","633","2879","3482"],"term_ids":["fgsea_msigdb_H_entrez:HALLMARK_APOPTOSIS"],"gene_set_hash":""}}   PASS     True          True              True       True             NaN          NaN          NaN                1.0            1b912bf139ec      f7243ee91cc9 1b912bf139ec             up
# c_66fdbb8a7099 HALLMARK_CHOLESTEROL_HOMEOSTASIS        up disease,tissue,perturbation,comparison fgsea_msigdb_H_entrez:HALLMARK_CHOLESTEROL_HOMEOSTASIS fgsea_msigdb_H_entrez HALLMARK_CHOLESTEROL_HOMEOSTASIS M0001__0df48c1b            NaN  5165,6811,1499,875,4047,10957,308,5833,2222,6721 fgsea_msigdb_H_entrez:HALLMARK_CHOLESTEROL_HOMEOSTASIS  01a3aafc0275              0      True            1.0       True          ok {"claim_id":"c_66fdbb8a7099","entity":"HALLMARK_CHOLESTEROL_HOMEOSTASIS","direction":"up","context_keys":["disease","tissue","perturbation","comparison"],"evidence_ref":{"module_id":"M0001__0df48c1b","gene_ids":["5165","6811","1499","875","4047","10957","308","5833","2222","6721"],"term_ids":["fgsea_msigdb_H_entrez:HALLMARK_CHOLESTEROL_HOMEOSTASIS"],"gene_set_hash":""}}   PASS     True          True              True       True             NaN          NaN          NaN                1.0            01a3aafc0275      a59af8d27fcb 01a3aafc0275             up
# c_3b50c19fc934             HALLMARK_P53_PATHWAY        up disease,tissue,perturbation,comparison             fgsea_msigdb_H_entrez:HALLMARK_P53_PATHWAY fgsea_msigdb_H_entrez             HALLMARK_P53_PATHWAY M0001__0df48c1b            NaN 4033,7062,5372,2258,3265,4084,3732,8626,1839,3691             fgsea_msigdb_H_entrez:HALLMARK_P53_PATHWAY  73cbba12ef1c              0      True            1.0       True          ok                        {"claim_id":"c_3b50c19fc934","entity":"HALLMARK_P53_PATHWAY","direction":"up","context_keys":["disease","tissue","perturbation","comparison"],"evidence_ref":{"module_id":"M0001__0df48c1b","gene_ids":["4033","7062","5372","2258","3265","4084","3732","8626","1839","3691"],"term_ids":["fgsea_msigdb_H_entrez:HALLMARK_P53_PATHWAY"],"gene_set_hash":""}}   PASS     True          True              True       True             NaN          NaN          NaN                1.0            73cbba12ef1c      d89dadd0d382 73cbba12ef1c             up
#
# [modules] n: 2 cols: ['module_id', 'n_terms', 'n_genes', 'rep_gene_ids', 'term_ids', 'rep_gene_ids_str', 'term_ids_str']
# [edges]   n: 1410 cols: ['term_uid', 'gene_id', 'weight', 'gene_term_degree', 'term_gene_degree']
#
# [modules] head:
#       module_id  n_terms  n_genes                                                                               rep_gene_ids                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            term_ids                                            rep_gene_ids_str                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       term_ids_str
# M0001__0df48c1b       18      382      ['100', '1001', '10014', '1002', '1006', '10097', '10113', '10160', '10174', '10197']                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            ['fgsea_msigdb_H_entrez:HALLMARK_ADIPOGENESI
SIGNALING,fgsea_msigdb_H_entrez:HALLMARK_INFLAMMATORY_RESPONSE,fgsea_msigdb_H_entrez:HALLMARK_INTERFERON_ALPHA_RESPONSE,fgsea_msigdb_H_entrez:HALLMARK_INTERFERON_GAMMA_RESPONSE,fgsea_msigdb_H_entrez:HALLMARK_KRAS_SIGNALING_DN,fgsea_msigdb_H_entrez:HALLMARK_KRAS_SIGNALING_UP,fgsea_msigdb_H_entrez:HALLMARK_MYC_TARGETS_V1,fgsea_msigdb_H_entrez:HALLMARK_MYC_TARGETS_V2,fgsea_msigdb_H_entrez:HALLMARK_MYOGENESIS,fgsea_msigdb_H_entrez:HALLMARK_NOTCH_SIGNALING,fgsea_msigdb_H_entrez:HALLMARK_PI3K_AKT_MTOR_SIGNALING,fgsea_msigdb_H_entrez:HALLMARK_PROTEIN_SECRETION,fgsea_msigdb_H_entrez:HALLMARK_REACTIVE_OXYGEN_SPECIES_PATHWAY,fgsea_msigdb_H_entrez:HALLMARK_SPERMATOGENESIS,fgsea_msigdb_H_entrez:HALLMARK_UV_RESPONSE_DN,fgsea_msigdb_H_entrez:HALLMARK_UV_RESPONSE_UP,fgsea_msigdb_H_entrez:HALLMARK_XENOBIOTIC_METABOLISM
#
# [edges] head:
#                                    term_uid  gene_id  weight  gene_term_degree  term_gene_degree
# fgsea_msigdb_H_entrez:HALLMARK_ADIPOGENESIS    10113     1.0                 2                28
# fgsea_msigdb_H_entrez:HALLMARK_ADIPOGENESIS    10989     1.0                 3                28
# fgsea_msigdb_H_entrez:HALLMARK_ADIPOGENESIS      112     1.0                 1                28
# fgsea_msigdb_H_entrez:HALLMARK_ADIPOGENESIS     1306     1.0                 1                28
# fgsea_msigdb_H_entrez:HALLMARK_ADIPOGENESIS     1337     1.0                 2                28
#
# [risk] shape: (1, 9)
# [risk] columns: ['coverage_pass_total', 'risk_fail_given_decided', 'risk_fail_total', 'fail_rate_total', 'n_pass', 'n_fail', 'n_abstain', 'n_total', 'threshold']
#
# [risk] head:
#  coverage_pass_total  risk_fail_given_decided  risk_fail_total  fail_rate_total  n_pass  n_fail  n_abstain  n_total  threshold
#                  1.0                      0.0              0.0              0.0     3.0     0.0        0.0      3.0        1.0
#
# [sample_card] keys: ['comparison', 'disease', 'extra', 'notes', 'perturbation', 'tissue']
# {
#   "disease": "HNSC",
#   "tissue": "tumor",
#   "perturbation": "genotype",
#   "comparison": "TP53_mut_vs_TP53_wt",
#   "notes": "TCGA Pan-Cancer; groups defined from MC3 TP53 PASS mutations.",
#   "extra": {
#     "benchmark_id": "PANCAN_TP53_v1",
#     "extra": {
#       "audit_tau": 0.2
#     },
#     "goal": "context-conditioned pathway claim selection with calibrated abstention",
#     "schema_version": "v1"
#   }
# } ...
#
# [SANITY][INFO] OK (sanity check complete)

# %%
for c in ("HNSC", "LUAD", "LUSC", "BRCA", "OV",  "UCEC",  "SKCM"):
    # !Rscript paper/scripts/fig2_fgsea_to_evidence_table.R $c
# Out:
# [fgsea_to_evidence] inputs
#   cancer: HNSC
#   rank: /work/paper/source_data/PANCAN_TP53_v1/derived/rankings/HNSC.deg_ranking.tsv
#   out : /work/paper/source_data/PANCAN_TP53_v1/evidence_tables/HNSC.evidence_table.tsv
#   msigdbr_version: 25.1.1
#   fgsea_version  : 1.36.2
#  [100%] Downloaded 33730584 bytes...
# Warning message:
# The `category` argument of `msigdbr()` is deprecated as of msigdbr 10.0.0.
# ℹ Please use the `collection` argument instead.
# Warning messages:
# 1: In fgsea(pathways = pathways, stats = stats, nperm = nperm) :
#   You are trying to run fgseaSimple. It is recommended to use fgseaMultilevel. To run fgseaMultilevel, you need to remove the nperm argument in the fgsea function call.
# 2: In preparePathwaysAndStats(pathways, stats, minSize, maxSize, gseaParam,  :
#   There are ties in the preranked stats (0.02% of the list).
# The order of those tied genes will be arbitrary, which may produce unexpected results.
# Error in setorderv(x, cols, order, na.last) :
#   some columns are not in the data.table: [abs]
# Calls: setorder -> setorderv -> stopf -> raise_condition -> signal
# Execution halted
# [fgsea_to_evidence] inputs
#   cancer: LUAD
#   rank: /work/paper/source_data/PANCAN_TP53_v1/derived/rankings/LUAD.deg_ranking.tsv
#   out : /work/paper/source_data/PANCAN_TP53_v1/evidence_tables/LUAD.evidence_table.tsv
#   msigdbr_version: 25.1.1
#   fgsea_version  : 1.36.2
# Warning message:
# The `category` argument of `msigdbr()` is deprecated as of msigdbr 10.0.0.
# ℹ Please use the `collection` argument instead.
# Warning messages:
# 1: In fgsea(pathways = pathways, stats = stats, nperm = nperm) :
#   You are trying to run fgseaSimple. It is recommended to use fgseaMultilevel. To run fgseaMultilevel, you need to remove the nperm argument in the fgsea function call.
# 2: In preparePathwaysAndStats(pathways, stats, minSize, maxSize, gseaParam,  :
#   There are ties in the preranked stats (0.08% of the list).
# The order of those tied genes will be arbitrary, which may produce unexpected results.
# Error in setorderv(x, cols, order, na.last) :
#   some columns are not in the data.table: [abs]
# Calls: setorder -> setorderv -> stopf -> raise_condition -> signal
# Execution halted
# [fgsea_to_evidence] inputs
#   cancer: LUSC
#   rank: /work/paper/source_data/PANCAN_TP53_v1/derived/rankings/LUSC.deg_ranking.tsv
#   out : /work/paper/source_data/PANCAN_TP53_v1/evidence_tables/LUSC.evidence_table.tsv
#   msigdbr_version: 25.1.1
#   fgsea_version  : 1.36.2
# ^C
# [fgsea_to_evidence] inputs
#   cancer: BRCA
#   rank: /work/paper/source_data/PANCAN_TP53_v1/derived/rankings/BRCA.deg_ranking.tsv
#   out : /work/paper/source_data/PANCAN_TP53_v1/evidence_tables/BRCA.evidence_table.tsv
#   msigdbr_version: 25.1.1
#   fgsea_version  : 1.36.2
# Warning message:
# The `category` argument of `msigdbr()` is deprecated as of msigdbr 10.0.0.
# ℹ Please use the `collection` argument instead.
# Warning messages:
# 1: In fgsea(pathways = pathways, stats = stats, nperm = nperm) :
#   You are trying to run fgseaSimple. It is recommended to use fgseaMultilevel. To run fgseaMultilevel, you need to remove the nperm argument in the fgsea function call.
# 2: In preparePathwaysAndStats(pathways, stats, minSize, maxSize, gseaParam,  :
#   There are ties in the preranked stats (0.04% of the list).
# The order of those tied genes will be arbitrary, which may produce unexpected results.
# Error in setorderv(x, cols, order, na.last) :
#   some columns are not in the data.table: [abs]
# Calls: setorder -> setorderv -> stopf -> raise_condition -> signal
# Execution halted
# [fgsea_to_evidence] inputs
#   cancer: OV
#   rank: /work/paper/source_data/PANCAN_TP53_v1/derived/rankings/OV.deg_ranking.tsv
#   out : /work/paper/source_data/PANCAN_TP53_v1/evidence_tables/OV.evidence_table.tsv
#   msigdbr_version: 25.1.1
#   fgsea_version  : 1.36.2
# Warning message:
# The `category` argument of `msigdbr()` is deprecated as of msigdbr 10.0.0.
# ℹ Please use the `collection` argument instead.
# Warning message:
# In fgsea(pathways = pathways, stats = stats, nperm = nperm) :
#   You are trying to run fgseaSimple. It is recommended to use fgseaMultilevel. To run fgseaMultilevel, you need to remove the nperm argument in the fgsea function call.
# Error in setorderv(x, cols, order, na.last) :
#   some columns are not in the data.table: [abs]
# Calls: setorder -> setorderv -> stopf -> raise_condition -> signal
# Execution halted
# [fgsea_to_evidence] inputs
#   cancer: UCEC
#   rank: /work/paper/source_data/PANCAN_TP53_v1/derived/rankings/UCEC.deg_ranking.tsv
#   out : /work/paper/source_data/PANCAN_TP53_v1/evidence_tables/UCEC.evidence_table.tsv
#   msigdbr_version: 25.1.1
#   fgsea_version  : 1.36.2
# Warning message:
# The `category` argument of `msigdbr()` is deprecated as of msigdbr 10.0.0.
# ℹ Please use the `collection` argument instead.
# Warning messages:
# 1: In fgsea(pathways = pathways, stats = stats, nperm = nperm) :
#   You are trying to run fgseaSimple. It is recommended to use fgseaMultilevel. To run fgseaMultilevel, you need to remove the nperm argument in the fgsea function call.
# 2: In preparePathwaysAndStats(pathways, stats, minSize, maxSize, gseaParam,  :
#   There are ties in the preranked stats (0.32% of the list).
# The order of those tied genes will be arbitrary, which may produce unexpected results.
# Error in setorderv(x, cols, order, na.last) :
#   some columns are not in the data.table: [abs]
# Calls: setorder -> setorderv -> stopf -> raise_condition -> signal
# Execution halted
# [fgsea_to_evidence] inputs
#   cancer: SKCM
#   rank: /work/paper/source_data/PANCAN_TP53_v1/derived/rankings/SKCM.deg_ranking.tsv
#   out : /work/paper/source_data/PANCAN_TP53_v1/evidence_tables/SKCM.evidence_table.tsv
#   msigdbr_version: 25.1.1
#   fgsea_version  : 1.36.2
# Warning message:
# The `category` argument of `msigdbr()` is deprecated as of msigdbr 10.0.0.
# ℹ Please use the `collection` argument instead.
# Warning messages:
# 1: In fgsea(pathways = pathways, stats = stats, nperm = nperm) :
#   You are trying to run fgseaSimple. It is recommended to use fgseaMultilevel. To run fgseaMultilevel, you need to remove the nperm argument in the fgsea function call.
# 2: In preparePathwaysAndStats(pathways, stats, minSize, maxSize, gseaParam,  :
#   There are ties in the preranked stats (0.6% of the list).
# The order of those tied genes will be arbitrary, which may produce unexpected results.
# Error in setorderv(x, cols, order, na.last) :
#   some columns are not in the data.table: [abs]
# Calls: setorder -> setorderv -> stopf -> raise_condition -> signal
# Execution halted

# %%
python paper/scripts/run_fig2_pipeline.py \
  --cancers HNSC,LUAD,LUSC,BRCA,OV,UCEC,SKCM \
  --variants ours,shuffled_context \
  --taus 0.2,0.4,0.6,0.8,0.9
